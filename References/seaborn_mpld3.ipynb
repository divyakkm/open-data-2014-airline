# %% [markdown]
# # Seaborn compatability with `mpld3`

# %% [markdown]
# See the [mpld3 github](https://github.com/jakevdp/mpld3) for more about mpl3d. See the [seaborn docs](stanford.edu/~mwaskom/software/seaborn/) for more about seaborn.
#
# Last updated December 30, 2013

# %%
import numpy as np
from numpy.random import randn
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import mpld3 as mpld3
from mpld3 import display_d3

# %%
np.random.seed(0)

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %%
x1 = randn(80)
x2 = randn(80)
x3 = x1 * x2
y1 = .5 + 2 * x1 - x2 + 2.5 * x3 + 3 * randn(80)
y2 = .5 + 2 * x1 - x2 + 2.5 * randn(80)
y3 = y2 + randn(80)
g = np.random.choice(list("ABC"), 80)
y_logistic = 1 / (1 + np.exp(-y1))
y_flip = [np.random.binomial(1, p) for p in y_logistic]
df = pd.DataFrame(dict(x1=x1, x2=x2, x3=x3, y1=y1, y2=y2, y3=y3, y_flip=y_flip, g=g))
d = randn(100, 30)

# %% [markdown]
# ## Basic aesthetics

# %%
sinplot()

# %%
sinplot()
display_d3()

# %%
sns.set(style="whitegrid")
sinplot()

# %%
sinplot()
mpld3.display()

# %%
sns.set(style="nogrid")
sinplot()
mpld3.display()

# %%
sinplot()
mpld3.display()

# %% [markdown]
# ## Linear model plots

# %%
sns.set()
mpld3.display()

# %%
sns.lmplot("x1", "y2", df)
fig = plt.gcf()

# %%
mpld3.display(fig)

# %%
sns.lmplot("x1", "y2", df, col="g", size=3.5)
fig = plt.gcf()
mpld3.display()

# %%
display_d3(fig)

# %%
sns.lmplot("x1", "y2", df, color="g")
fig = plt.gcf()

# %%
display_d3(fig)

# %%
sns.regplot("x1", "y1", df)
fig = plt.gcf()

# %%
display_d3(fig)

# %%
sns.coefplot("y1 ~ x1 * x2 + g", df)
fig = plt.gcf()

# %%
display_d3(fig)

# %%
sns.interactplot("x1", "x2", "y1", df)
fig = plt.gcf()

# %%
display_d3(fig)

# %%
sns.corrplot(df)
fig = plt.gcf()

# %%
mpld3.display(fig)

# %% [markdown]
# ## Distribution plots

# %%
sns.boxplot(df.x1, df.g)
fig = plt.gcf()

# %%
display_d3(fig)

# %%
sns.violinplot(df.x1, df.g)
fig = plt.gcf()

# %%
display_d3(fig)

# %%
sns.distplot(df.x1)
fig = plt.gcf()

# %%
display_d3(fig)

# %%
sns.kdeplot(df.x1, shade=True)
fig = plt.gcf()

# %%
display_d3(fig)

# %%
sns.kdeplot(df[["x1", "x2"]])
fig = plt.gcf()

# %%
display_d3(fig)

# %%
sns.kdeplot(df[["x1", "x2"]], shade=True)
fig = plt.gcf()

# %%
display_d3(fig)

# %% [markdown]
# ## Timeseries plots

# %%
def random_walk(n, start=0, p_inc=.2):
    return start + np.cumsum(np.random.uniform(size=n) < p_inc)
starts = np.random.choice(range(4), 10)
probs = [.1, .3, .5]
walks = np.dstack([[random_walk(15, s, p) for s in starts] for p in probs])

# %%
sns.tsplot(walks)
fig = plt.gcf()

# %%
display_d3(fig)
# Out:
# C:\Anaconda\lib\site-packages\mpld3\utils.py:23: DeprecationWarning: mpld3.display_d3 is deprecated and will be removed.  Use mpld3.display instead
#   category=DeprecationWarning)
# <style>
#
# </style>
#
# <div id="fig65763762929122050668418"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# function create_fig65763762929122050668418(){
#
#   mpld3.draw_figure("fig65763762929122050668418", {"width": 640.0, "axes": [{"xlim": [0.0, 14.0], "yscale": "linear", "axesbg": "#EAEAF2", "texts": [], "zoomable": true, "images": [], "xdomain": [0.0, 14.0], "ylim": [1.0, 11.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "position": "bottom", "nticks": 8, "tickvalues": null, "tickformat": null}, {"grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "position": "left", "nticks": 7, "tickvalues": null, "tickformat": null}], "lines": [{"color": "#4C72B0", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "6576382361728"}, {"color": "#55A868", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "6576379288880"}, {"color": "#C44E52", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "6576379288376"}], "markers": [], "id": "6576379372264", "ydomain": [1.0, 11.0], "collections": [{"paths": [[[[0.0, 2.2], [0.0, 1.6], [1.0, 1.6], [2.0, 1.7], [3.0, 1.7], [4.0, 1.8], [5.0, 1.9], [6.0, 2.0], [7.0, 2.0], [8.0, 2.1], [9.0, 2.1], [10.0, 2.4], [11.0, 2.6], [12.0, 2.6], [13.0, 2.8], [14.0, 2.8], [14.0, 3.2], [14.0, 3.2], [13.0, 3.2], [12.0, 3.2], [11.0, 3.2], [10.0, 3.0], [9.0, 2.8], [8.0, 2.7], [7.0, 2.6], [6.0, 2.6], [5.0, 2.5], [4.0, 2.4], [3.0, 2.3], [2.0, 2.3], [1.0, 2.2], [0.0, 2.2]], ["M", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "Z"]]], "edgecolors": ["#4C72B0"], "edgewidths": [0.3], "offsets": "data02", "yindex": 1, "id": "6576379289104", "pathtransforms": [], "pathcoordinates": "data", "offsetcoordinates": "display", "zorder": 1, "xindex": 0, "alphas": [0.2], "facecolors": ["#4C72B0"]}, {"paths": [[[[0.0, 2.6], [0.0, 2.0], [1.0, 2.4], [2.0, 2.5], [3.0, 2.5], [4.0, 3.1], [5.0, 3.5], [6.0, 3.7], [7.0, 3.9], [8.0, 4.2], [9.0, 4.6], [10.0, 4.8], [11.0, 5.1], [12.0, 5.4], [13.0, 6.2], [14.0, 6.4], [14.0, 7.9], [14.0, 7.9], [13.0, 7.7], [12.0, 6.8], [11.0, 6.5], [10.0, 6.1], [9.0, 5.9], [8.0, 5.4], [7.0, 4.9], [6.0, 4.7], [5.0, 4.3], [4.0, 3.9], [3.0, 3.5], [2.0, 3.3], [1.0, 3.2], [0.0, 2.6]], ["M", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "Z"]]], "edgecolors": ["#55A868"], "edgewidths": [0.3], "offsets": "data02", "yindex": 0, "id": "6576382226104", "pathtransforms": [], "pathcoordinates": "data", "offsetcoordinates": "display", "zorder": 1, "xindex": 0, "alphas": [0.2], "facecolors": ["#55A868"]}, {"paths": [[[[0.0, 2.8], [0.0, 2.2], [1.0, 2.4], [2.0, 3.0], [3.0, 3.8], [4.0, 4.1], [5.0, 4.6], [6.0, 5.2], [7.0, 5.4], [8.0, 6.0], [9.0, 6.3], [10.0, 7.0], [11.0, 7.5], [12.0, 8.2], [13.0, 8.7], [14.0, 9.0], [14.0, 10.4], [14.0, 10.4], [13.0, 9.9], [12.0, 9.4], [11.0, 8.6], [10.0, 7.8], [9.0, 7.3], [8.0, 7.0], [7.0, 6.5], [6.0, 6.2], [5.0, 5.5], [4.0, 4.9], [3.0, 4.4], [2.0, 3.7], [1.0, 3.0], [0.0, 2.8]], ["M", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "L", "Z"]]], "edgecolors": ["#C44E52"], "edgewidths": [0.3], "offsets": "data02", "yindex": 0, "id": "6576379354304", "pathtransforms": [], "pathcoordinates": "data", "offsetcoordinates": "display", "zorder": 1, "xindex": 0, "alphas": [0.2], "facecolors": ["#C44E52"]}], "xscale": "linear", "bbox": [0.125, 0.099999999999999978, 0.77500000000000002, 0.80000000000000004]}], "data": {"data02": [[0.0, 0.0]], "data01": [[0.0, 1.9, 2.3, 2.5], [1.0, 1.9, 2.8, 2.7], [2.0, 2.0, 2.9, 3.3], [3.0, 2.0, 3.0, 4.1], [4.0, 2.1, 3.5, 4.5],  ...
# }
#
# if(typeof(mpld3) !== "undefined"){
#    // already loaded: just create the figure
#    create_fig65763762929122050668418();
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "http://d3js.org/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("http://mpld3.github.io/js/mpld3.v0.1.js", create_fig65763762929122050668418);
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("http://d3js.org/d3.v3.min.js", function(){
#         mpld3_load_lib("http://mpld3.github.io/js/mpld3.v0.1.js", create_fig65763762929122050668418);})
# }
# </script>

# %%
sns.tsplot(walks, err_style="ci_bars")
fig = plt.gcf()

# %%
display_d3(fig)
# Out:
# C:\Anaconda\lib\site-packages\mpld3\utils.py:23: DeprecationWarning: mpld3.display_d3 is deprecated and will be removed.  Use mpld3.display instead
#   category=DeprecationWarning)
# <style>
#
# </style>
#
# <div id="fig65763823285048595543839"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# function create_fig65763823285048595543839(){
#
#   mpld3.draw_figure("fig65763823285048595543839", {"width": 640.0, "axes": [{"xlim": [0.0, 14.0], "yscale": "linear", "axesbg": "#EAEAF2", "texts": [], "zoomable": true, "images": [], "xdomain": [0.0, 14.0], "ylim": [1.0, 11.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "position": "bottom", "nticks": 8, "tickvalues": null, "tickformat": null}, {"grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "position": "left", "nticks": 7, "tickvalues": null, "tickformat": null}], "lines": [{"color": "#4C72B0", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "6576403738696"}, {"color": "#4C72B0", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 2, "linewidth": 1.75, "data": "data01", "id": "6576403739144"}, {"color": "#4C72B0", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "6576403740656"}, {"color": "#4C72B0", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 2, "linewidth": 1.75, "data": "data02", "id": "6576403742056"}, {"color": "#4C72B0", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data03", "id": "6576403809056"}, {"color": "#4C72B0", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data04", "id": "6576403810400"}, {"color": "#4C72B0", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data05", "id": "6576403811800"}, {"color": "#4C72B0", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 2, "linewidth": 1.75, "data": "data05", "id": "6576403747728"}, {"color": "#4C72B0", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data06", "id": "6576403749128"}, {"color": "#4C72B0", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data07", "id": "6576403750528"}, {"color": "#4C72B0", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data08", "id": "6576403641400"}, {"color": "#4C72B0", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data09", "id": "6576403642800"}, {"color": "#4C72B0", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 2, "linewidth": 1.75, "data": "data09", "id": "6576403644200"}, {"color": "#4C72B0", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data10", "id": "6576403666144"}, {"color": "#4C72B0", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 2, "linewidth": 1.75, "data": "data10", "id": "6576403667544"}, {"color": "#4C72B0", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data11", "id": "6576403762928"}, {"color": "#55A868", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "6576403650992"}, {"color": "#55A868", "yindex": 4, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 2, "linewidth": 1.75, "data": "data01", "id": "6576403651496"}, {"color": "#55A868", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data02", "id": "6576403829088"}, {"color": "# ...

# %%
def sine_wave(n_x, obs_err_sd=1.5, tp_err_sd=.3):
    x = np.linspace(0, (n_x - 1) / 2, n_x)
    y = np.sin(x) + np.random.normal(0, obs_err_sd) + np.random.normal(0, tp_err_sd, n_x)
    return y
sines = np.array([sine_wave(31) for _ in range(20)])

# %%
sns.tsplot(sines, err_style="boot_traces", n_boot=500)
fig = plt.gcf()

# %%
display_d3(fig)
# Out:
# C:\Anaconda\lib\site-packages\mpld3\utils.py:23: DeprecationWarning: mpld3.display_d3 is deprecated and will be removed.  Use mpld3.display instead
#   category=DeprecationWarning)
# <style>
#
# </style>
#
# <div id="fig65763822835605230602843"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# function create_fig65763822835605230602843(){
#
#   mpld3.draw_figure("fig65763822835605230602843", {"width": 640.0, "axes": [{"xlim": [0.0, 30.0], "yscale": "linear", "axesbg": "#EAEAF2", "texts": [], "zoomable": true, "images": [], "xdomain": [0.0, 30.0], "ylim": [-2.0, 2.5], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "position": "bottom", "nticks": 7, "tickvalues": null, "tickformat": null}, {"grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "position": "left", "nticks": 10, "tickvalues": null, "tickformat": null}], "lines": [{"color": "#4C72B0", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.25, "xindex": 0, "linewidth": 0.25, "data": "data01", "id": "6576402798072"}, {"color": "#4C72B0", "yindex": 2, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.25, "xindex": 0, "linewidth": 0.25, "data": "data01", "id": "6576402798688"}, {"color": "#4C72B0", "yindex": 3, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.25, "xindex": 0, "linewidth": 0.25, "data": "data01", "id": "6576402799192"}, {"color": "#4C72B0", "yindex": 4, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.25, "xindex": 0, "linewidth": 0.25, "data": "data01", "id": "6576402799584"}, {"color": "#4C72B0", "yindex": 5, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.25, "xindex": 0, "linewidth": 0.25, "data": "data01", "id": "6576402799976"}, {"color": "#4C72B0", "yindex": 6, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.25, "xindex": 0, "linewidth": 0.25, "data": "data01", "id": "6576402800368"}, {"color": "#4C72B0", "yindex": 7, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.25, "xindex": 0, "linewidth": 0.25, "data": "data01", "id": "6576402825400"}, {"color": "#4C72B0", "yindex": 8, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.25, "xindex": 0, "linewidth": 0.25, "data": "data01", "id": "6576402825792"}, {"color": "#4C72B0", "yindex": 9, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.25, "xindex": 0, "linewidth": 0.25, "data": "data01", "id": "6576402826184"}, {"color": "#4C72B0", "yindex": 10, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.25, "xindex": 0, "linewidth": 0.25, "data": "data01", "id": "6576402826576"}, {"color": "#4C72B0", "yindex": 11, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.25, "xindex": 0, "linewidth": 0.25, "data": "data01", "id": "6576402826968"}, {"color": "#4C72B0", "yindex": 12, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.25, "xindex": 0, "linewidth": 0.25, "data": "data01", "id": "6576402827360"}, {"color": "#4C72B0", "yindex": 13, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.25, "xindex": 0, "linewidth": 0.25, "data": "data01", "id": "6576402827752"}, {"color": "#4C72B0", "yindex": 14, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.25, "xindex": 0, "linewidth": 0.25, "data": "data01", "id": "6576402828144"}, {"color": "#4C72B0", "yindex": 15, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.25, "xindex": 0, "linewidth": 0.25, "data": "data01", "id": "6576402828536"}, {"color": "#4C72B0", "yindex": 16, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.25, "xindex": 0, "linewidth": 0.25, "data": "data01", "id": "6576402828928"}, {"color": "#4C72B0", "yindex": 17, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.25, "xindex": 0, "linewidth": 0.25, "data": "data01", "id": "6576402833480"}, {"color": "#4C72B0", "yindex": 18, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.25, "xindex": 0, "linewidth": 0.25, "data": "data01", "id": "6576402833872"}, {"color": "#4C72B0", "yindex": 19, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.25, "xindex": 0, "line ...

# %%
sns.tsplot(sines, err_style="boot_kde", n_boot=500)
fig = plt.gcf()

# %%
display_d3(fig)
# Out:
# C:\Anaconda\lib\site-packages\mpld3\utils.py:23: DeprecationWarning: mpld3.display_d3 is deprecated and will be removed.  Use mpld3.display instead
#   category=DeprecationWarning)
# <style>
#
# </style>
#
# <div id="fig65764037834646301129481"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# function create_fig65764037834646301129481(){
#
#   mpld3.draw_figure("fig65764037834646301129481", {"width": 640.0, "axes": [{"xlim": [0.0, 30.0], "yscale": "linear", "axesbg": "#EAEAF2", "texts": [], "zoomable": true, "images": [{"coordinates": "data", "zorder": 2, "extent": [0.0, 30.0, -1.8469809206687688, 2.4202331090648559], "alpha": null, "data": "...", "id": "6576427711904"}], "xdomain": [0.0, 30.0], "ylim": [-2.0, 2.5], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "position": "bottom", "nticks": 7, "tickvalues": null, "tickformat": null}, {"grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "position": "left", "nticks": 10, "tickvalues": null, "tickformat": null}], "lines": [{"color": "#4C72B0", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.75, "data": "data01", "id": "6576427711680"}], "markers": [], "id": "6576402735736", "ydomain": [-2.0, 2.5], "collections": [], "xscale": "linear", "bbox": [0.125, 0.099999999999999978, 0.77500000000000002, 0.80000000000000004]}], "data": {"data01": [[0.0, 0.21695479323531006], [1.0, 0.7823005174642871], [2.0, 1.223209458957808], [3.0, 1.2364865331032215], [4.0, 1.21072375748761], [5.0, 0.8319965925263872], [6.0, 0.4459718115707402], [7.0, -0.013711653569428297], [8.0, -0.4445814696747313], [9.0, -0.7657777719791745], [10.0, -0.7856910164490355], [11.0, -0.4349824349872408], [12.0, -0.07659775082654562], [13.0, 0.5321354535503546], [14.0, 0.8531602987240581], [15.0, 1.213476517430241], [16.0, 1.3110055003878118], [17.0, 1.085267483687825], [18.0, 0.6667105303316604], [19.0, 0.15567978142179853], [20.0, -0.36652148611837837], [21.0, -0.6766649070433128], [22.0, -0.7581118385116242], [23.0, -0.707667832836964], [24.0, -0.3317753002983263], [25.0, 0.17253663710470912], [26.0, 0.6822708326919754], [27.0, 1.1247861477152246], [28.0, 1.229501986249955], [29.0, 1.257295903313887], [30.0, 0.8395530017932302]]}, "id": "6576403783464", "toolbar": ["reset", "move"], "height": 440.0});
# }
#
# if(typeof(mpld3) !== "undefined"){
#    // already loaded: just create the figure
#    create_fig65764037834646301129481();
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "http://d3js.org/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("http://mpld3.github.io/js/mpld3.v0.1.js", create_fig65764037834646301129481);
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("http://d3js.org/d3.v3.min.js", function(){
#         mpld3_load_lib("http://mpld3.github.io/js/mpld3.v0.1.js", create_fig65764037834646301129481);})
# }
# </script>
