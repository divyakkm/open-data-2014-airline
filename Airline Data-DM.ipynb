# %% [markdown]
# # Analyzing Airline On Time Data

# %% [markdown]
# #### Team

# %% [markdown]
# Divya Menghani, Dheera Tallapragada, Rahul Verma

# %% [markdown]
# #### About Our Project

# %% [raw]
# As a group, we share common love for air-travel and curiosity about the airline industry. The recent missing Malaysian airline plane related incident spurred our interest further and made us realize how little we know about airlines, their schedules and their function in general. We began researching and stumbled upon US DoT dataset on their website, which looked pretty exhaustive and promising.
#
# By exploring this dataset, we intend to understand how the US airline industry operates. We plan to achieve this by finding out the most important/popular carriers in the country, understanding their performance - about delays and the causes for the delays, what cities they affect. In the process, we hope to unravel some interesting trends in the last few years in the US airline industry with the help of data visualizations.
#
# The United States Department of Transportation tracks the on-time performance of domestic flights operated by large air carriers. Airlines are required to report their on-time performance to the U.S. Department of Transportation and have been doing so since 1987. The U.S. Department of Transportation publishes a monthly summary of airline on-time performance, including causes of delay, in the Air Travel Consumer Report along with an annual reports on variety of on-time and flight delay information so that the public would have clear information about the nature and sources of airline delays and cancellations.
#
# Each year’s data contains on-time arrival data for non-stop domestic flights by major air carriers, and provides such additional items as departure and arrival delays, origin and destination airports, flight numbers, scheduled and actual departure and arrival times, cancelled or diverted flights, taxi-out and taxi-in times, air time, and non-stop distance.
#
# Some of the questions which we want to investigate are (tentative list):
#
# 1. When is the best time of day/day of week/time of year to fly to minimize delays?
# 2. Visualize a week at SFO airport
# 3. Relationship between season and delays
# 4. Worst and Best airports for delays
# 5. Busiest airport routes

# %% [markdown]
# #### Our Datasets

# %% [markdown]
# We will be working with airline data for individual years found at http://stat-computing.org/dataexpo/2009/the-data.html.
# Additionally, we will also be using supplemental data sets about airports, carriers, plane-data and weather data found at http://stat-computing.org/dataexpo/2009/supplemental-data.html.

# %% [markdown]
# # BASIC CODE TO ACCESS THE OPEN DATASETS

# %% [markdown]
# Download the CSV file for any year of your choice from http://stat-computing.org/dataexpo/2009/the-data.html. Place it in you local drive (E.g C:\Users\Admin\Supplemental_data) and assign this path to the variable "INPUT_FILE_PATH" declared under "global constants".

# %%
#  Importing various modules

from __future__ import division
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from pylab import figure, show
from pandas import DataFrame, Series
import pandas as pd
import csv
import os
import statsmodels.formula.api as smf
import scipy.stats as stats
import statsmodels.api as sm
from IPython.core.display import HTML
from bokeh.plotting import *
output_notebook()
import seaborn as sns
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>Bokeh Plot</title>
#         <style>
#             /* BEGIN C:\Anaconda\lib\site-packages\bokeh\server\static\css\bokeh.min.css */
#             /*!
#              * Bootstrap v2.0.4
#              *
#              * Copyright 2012 Twitter, Inc
#              * Licensed under the Apache License v2.0
#              * http://www.apache.org/licenses/LICENSE-2.0
#              *
#              * Designed and built with all the love in the world @twitter by @mdo and @fat.
# ...

# %%
#  Setting global constants. Please initialize this before running the code

TRAINING_LINE_NUMBER = 100 # Number of lines to be read from the huge file, set to total file length while running for entire file
INPUT_FILE_PATH="C:\\data\\airline\\" # Path of the folder where you have placed your files
SKIP_FIRST_LINE = True # To skip the first line, as its the header
YEARS = ['2008'] # Add more years in this list and add the files in the INPUT_FILE_PATH
INPUT_DELAY = 15 # Delay threshold to be considered while plotting graphs

# %%
# Setting the dataframes for Airline, Plane and Carriers

try:
    path = INPUT_FILE_PATH + "plane-data.csv"
    dfPlane = pd.read_csv(path, parse_dates=True, dayfirst=False)
    path = INPUT_FILE_PATH + "airports.csv"
    dfAirport = pd.read_csv(path)
    path = INPUT_FILE_PATH + "carriers.csv"
    dfCarrier = pd.read_csv(path)
except Exception as e:
    print "Supplemental Data Import failed", e

# %%
# Reading the main file in a Pandas dataframe

try:
    for year in YEARS:
        path = os.path.join(INPUT_FILE_PATH, '%d.csv' % int(year))
        dfMaster = pd.read_csv(path, nrows=TRAINING_LINE_NUMBER,skiprows=0)
#         dfMaster = pd.read_csv(path,skiprows=0)
except Exception as e:
    print "Supplemental Data Import failed", e

dfMaster[dfMaster['Dest']=='TPA']
dfMaster.to_csv()
# Out:
#     Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0   2008      1           3          4     2003        1955     2211
# 1   2008      1           3          4      754         735     1002
# 18  2008      1           3          4     1323        1255     1526
# 44  2008      1           3          4     1153        1140     1428
# 45  2008      1           3          4     1528        1510     1802
# 46  2008      1           3          4      634         635      907
# 76  2008      1           3          4     1318        1310     1410
# 77  2008      1           3          4      958         900     1052
# 78  2008      1           3          4     1859        1850     1950
#
#     CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# 0         2225            WN        335  N712SW                128
# 1         1000            WN       3231  N772SW                128
# 18        1510            WN          4  N674AA                123
# ...

# %% [markdown]
# Displaying the data present in the master file

# %%
dfMaster.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4     2003        1955     2211
# 1  2008      1           3          4      754         735     1002
# 2  2008      1           3          4      628         620      804
# 3  2008      1           3          4      926         930     1054
# 4  2008      1           3          4     1829        1755     1959
#
#    CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# 0        2225            WN        335  N712SW                128
# 1        1000            WN       3231  N772SW                128
# 2         750            WN        448  N428WN                 96
# 3        1100            WN       1746  N612SW                 88
# 4        1925            WN       3920  N464WN                 90
#
#    CRSElapsedTime  AirTime  ArrDelay  DepDelay Origin Dest  Distance  TaxiIn  \
# 0             150      116       -14         8    IAD  TPA       810       4
# ...

# %%
dfMaster.fillna(0,inplace=True)

# %%
# TODO: Do this for other dataframes as well

#  Convert all columns to respective datatypes

dfMaster['Year'] = dfMaster['Year'].astype('int')
dfMaster['Month'] = dfMaster['Month'].astype('int')
dfMaster['DayofMonth'] = dfMaster['DayofMonth'].astype('int')
dfMaster['DayOfWeek'] = dfMaster['DayOfWeek'].astype('int')
dfMaster['DepTime'] = dfMaster['DepTime'].astype('int')
dfMaster['CRSDepTime'] = dfMaster['CRSDepTime'].astype('int')
dfMaster['ArrTime'] = dfMaster['ArrTime'].astype('int')
dfMaster['CRSArrTime'] = dfMaster['CRSArrTime'].astype('int')
dfMaster['FlightNum'] = dfMaster['FlightNum'].astype('int')
dfMaster['ActualElapsedTime'] = dfMaster['ActualElapsedTime'].astype('int')
dfMaster['CRSElapsedTime'] = dfMaster['CRSElapsedTime'].astype('int')
dfMaster['AirTime'] = dfMaster['AirTime'].astype('int')
dfMaster['ArrDelay'] = dfMaster['ArrDelay'].astype('int')
dfMaster['DepDelay'] = dfMaster['DepDelay'].astype('int')
dfMaster['Distance'] = dfMaster['Distance'].astype('int')
dfMaster['TaxiIn'] = dfMaster['TaxiIn'].astype('int')
dfMaster['TaxiOut'] = dfMaster['TaxiOut'].astype('int')
dfMaster['Cancelled'] = dfMaster['Cancelled'].astype('int')
dfMaster['Diverted'] = dfMaster['Diverted'].astype('int')
print dfMaster.columns
# Out:
# Index([u'Year', u'Month', u'DayofMonth', u'DayOfWeek', u'DepTime', u'CRSDepTime', u'ArrTime', u'CRSArrTime', u'UniqueCarrier', u'FlightNum', u'TailNum', u'ActualElapsedTime', u'CRSElapsedTime', u'AirTime', u'ArrDelay', u'DepDelay', u'Origin', u'Dest', u'Distance', u'TaxiIn', u'TaxiOut', u'Cancelled', u'CancellationCode', u'Diverted', u'CarrierDelay', u'WeatherDelay', u'NASDelay', u'SecurityDelay', u'LateAircraftDelay'], dtype='object')

# %% [markdown]
# Displaying data in Airport file

# %%
dfAirport.head()
# Out:
#   iata               airport              city state country        lat  \
# 0  00M              Thigpen        Bay Springs    MS     USA  31.953765
# 1  00R  Livingston Municipal        Livingston    TX     USA  30.685861
# 2  00V           Meadow Lake  Colorado Springs    CO     USA  38.945749
# 3  01G          Perry-Warsaw             Perry    NY     USA  42.741347
# 4  01J      Hilliard Airpark          Hilliard    FL     USA  30.688012
#
#          long
# 0  -89.234505
# 1  -95.017928
# 2 -104.569893
# 3  -78.052081
# 4  -81.905944
#
# [5 rows x 7 columns]

# %% [markdown]
# Displaying data in Carrier file

# %%
dfCarrier.head()
# Out:
#   Code                    Description
# 0  02Q                  Titan Airways
# 1  04Q             Tradewind Aviation
# 2  05Q            Comlux Aviation, AG
# 3  06Q  Master Top Linhas Aereas Ltd.
# 4  07Q            Flair Airlines Ltd.
#
# [5 rows x 2 columns]

# %% [markdown]
# Displaying data in Plane file

# %%
dfPlane.head()
# Out:
#   tailnum type manufacturer issue_date model status aircraft_type engine_type  \
# 0  N050AA  NaN          NaN        NaN   NaN    NaN           NaN         NaN
# 1  N051AA  NaN          NaN        NaN   NaN    NaN           NaN         NaN
# 2  N052AA  NaN          NaN        NaN   NaN    NaN           NaN         NaN
# 3  N054AA  NaN          NaN        NaN   NaN    NaN           NaN         NaN
# 4  N055AA  NaN          NaN        NaN   NaN    NaN           NaN         NaN
#
#   year
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
# [5 rows x 9 columns]

# %% [markdown]
# Renaming the Origin column as 'iata' in order to merge with Airports dataframe and renaming the new columns as 'Origin_'

# %%
dfMaster.rename(columns={'Origin' : 'iata'}, inplace=True)
dfMaster = pd.merge(dfMaster, dfAirport, on='iata', how = 'inner')
dfMaster.rename(columns={'iata' : 'Origin', 'airport' : 'Origin_airport', 'city' : 'Origin_city', 'state' : 'Origin_state', 'country' : 'Origin_country', 'lat' : 'Origin_lat', 'long' : 'Origin_long'}, inplace='True')

# %% [markdown]
# Renaming the Dest column as 'iata' in order to merge with Airports dataframe and renaming the new columns as 'Dest_'

# %%
dfMaster.rename(columns={'Dest' : 'iata'}, inplace=True)
dfMaster = pd.merge(dfMaster, dfAirport, on='iata', how = 'inner')
dfMaster.rename(columns={'iata' : 'Dest', 'airport' : 'Dest_airport', 'city' : 'Dest_city', 'state' : 'Dest_state', 'country' : 'Dest_country', 'lat' : 'Dest_lat', 'long' : 'Dest_long'}, inplace='True')

# %% [markdown]
# Renaming the UniqueCarrier column as 'Code' in order to merge with Carrier dataframe and renaming the new columns as 'Dest_'

# %%
dfMaster.rename(columns={'UniqueCarrier' : 'Code'}, inplace=True)
dfMaster = pd.merge(dfMaster, dfCarrier, on='Code', how = 'inner')
dfMaster.rename(columns={'Code' : 'UniqueCarrier', 'Description' : 'Carrier_Description'}, inplace='True')

# %%
dfMaster['FlightDate'] =pd.to_datetime(dfMaster.Year*10000+dfMaster.Month*100+dfMaster.DayofMonth,format='%Y%m%d')
dfMaster.set_index(dfMaster.FlightDate,inplace=True)
dfMaster.index.dtype
dfMaster.columns
dfMaster['2008'].head()
# Out:
#             Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# FlightDate
# 2008-01-03  2008      1           3          4     2003        1955     2211
# 2008-01-03  2008      1           3          4      754         735     1002
# 2008-01-04  2008      1           4          5     2002        1955     2208
# 2008-01-04  2008      1           4          5      734         735      938
# 2008-01-05  2008      1           5          6     2000        1955     2214
#
#             CRSArrTime UniqueCarrier  FlightNum TailNum  ActualElapsedTime  \
# FlightDate
# 2008-01-03        2225            WN        335  N712SW                128
# 2008-01-03        1000            WN       3231  N772SW                128
# 2008-01-04        2225            WN        335  N219WN                126
# 2008-01-04        1000            WN       3231  N299WN                124
# 2008-01-05        2225            WN        335  N410WN                134
#
# ...

# %%
dfMaster.rename(columns={'UniqueCarrier' : 'Code'}, inplace=True)
dfMaster = pd.merge(dfMaster, dfCarrier, on='Code', how = 'inner')
dfMaster.rename(columns={'Code' : 'UniqueCarrier', 'Description' : 'Carrier_Description'}, inplace='True')

# %%
# dfCarrierStats = dfMaster['ArrDelay','UniqueCarrier','DepDelay']].groupby([dfMaster['UniqueCarrier']]).agg([np.sum, np.mean, np.std, len])
# # dfCarrierStats

# %%
# dfArrvCarrierStats = dfMaster[['ArrDelay','UniqueCarrier']][dfMaster['ArrDelay'] > INPUT_DELAY].groupby([dfMaster['UniqueCarrier']]).agg([np.sum, np.mean, np.std, len])
# dfArrvCarrierStats 

# dfDepCarrierStats = dfMaster[['UniqueCarrier','DepDelay']][dfMaster['DepDelay'] > INPUT_DELAY].groupby([dfMaster['UniqueCarrier']]).agg([np.sum, np.mean, np.std, len])
# dfDepCarrierStats 

# dfCarrierStats = pd.concat((dfArrvCarrierStats , dfDepCarrierStats), axis = 1)
# #dfCarrDelay_count.columns = ['ArrivalDelay_count', 'DepartureDelay_count']

# %%
# dfCarrierStats

# %% [markdown]
# Delays by carrier - Arrival-Departure
# Count
# Average of delay

# %%
dfArrvAirportStats = dfMaster[['ArrDelay','Origin_airport']][dfMaster['ArrDelay'] > INPUT_DELAY].groupby([dfMaster['Origin_airport']]).agg([np.sum, np.mean, np.std, len])
dfArrvAirportStats

dfDepAirportStats = dfMaster[['Origin_airport','DepDelay']][dfMaster['DepDelay'] > INPUT_DELAY].groupby([dfMaster['Origin_airport']]).agg([np.sum, np.mean, np.std, len])
dfDepAirportStats

dfAiportStats = pd.concat((dfArrvAirportStats , dfDepAirportStats), axis = 1)

# %%
dfAiportStats.head()
# Out:
#                        ArrDelay                               DepDelay  \
#                             sum        mean         std  len       sum
# Abilene Regional           4679  103.977778  131.500689   45      4059
# Adams                     17223   61.074468   59.064035  282     16058
# Akron-Canton Regional     10180   57.191011   75.818752  178      8028
# Albany Cty                15565   57.014652   59.001182  273     12852
# Albert J Ellis              899   56.187500   37.413400   16       919
#
#
#                              mean         std  len
# Abilene Regional       119.382353  135.949637   34
# Adams                   59.917910   57.827659  268
# Akron-Canton Regional   72.324324   84.862259  111
# Albany Cty              60.338028   65.133233  213
# Albert J Ellis          51.055556   41.552904   18
#
# [5 rows x 8 columns]

# %% [markdown]
# Delays by Airport City - Arrival and Dep
# Count
# Average of delay

# %% [markdown]
# Delays by Airport City - Arrival and Dep Count (Average and count). Placeholder

# %% [markdown]
# dDfMasterPlane only have limited columns for merging with plane dataframe.

# %%
# Divi start code here!
def percentile(n):
    def percentile_(x):
        return np.percentile(x, n)
    percentile_.__name__ = 'percentile_%s' % n
    return percentile_

# %%
dfArrDelayTimeStats = dfMaster[['FlightDate','Dest','ArrDelay']][dfMaster['ArrDelay'] > INPUT_DELAY].groupby([dfMaster['FlightDate'],dfMaster['Dest']]). \
agg([np.sum, np.mean, np.std, len,percentile(25),percentile(50),percentile(75)])
dfArrDelayTimeStats.reset_index(inplace=True)

# %%
df1 = pd.DataFrame( { 
    "Name" : ["Alice", "Bob", "Mallory", "Mallory", "Bob" , "Mallory"] , 
    "City" : ["Seattle", "Seattle", "Portland", "Seattle", "Seattle", "Portland"] } )
df1.index
df1.columns
g1 = df1.groupby( [ "Name", "City"] ).count()
g1.add_suffix('_Count').reset_index(inplace=True)
g1.index
# Out:
# MultiIndex(levels=[[u'Alice', u'Bob', u'Mallory'], [u'Portland', u'Seattle']],
#            labels=[[0, 1, 2, 2], [1, 1, 0, 1]],
#            names=[u'Name', u'City'])

# %%
def random_walk(n, start=0, p_inc=.2):
    return start + np.cumsum(np.random.uniform(size=n) < p_inc)

starts = np.random.choice(range(4), 10)
probs = [.1, .3, .5]
walks = np.dstack([[random_walk(15, s, p) for s in starts] for p in probs])

step = pd.Series(range(1, 16), name="step")
speed = pd.Series(["slow", "average", "fast"], name="speed")
sns.tsplot(walks, time=step, condition=speed, value="position");

# %%
def sine_wave(n_x, obs_err_sd=1.5, tp_err_sd=.3):
    x = np.linspace(0, (n_x - 1) / 2, n_x)
    y = np.sin(x) + np.random.normal(0, obs_err_sd) + np.random.normal(0, tp_err_sd, n_x)
    return y
sines = np.array([sine_wave(31) for _ in range(20)])
sines.shape
# Out:
# (20L, 31L)

# %%
dfDepDelayTimeStats = dfMaster[['FlightDate','Origin','DepDelay']][dfMaster['DepDelay'] > INPUT_DELAY].groupby([dfMaster['FlightDate'],dfMaster['Origin']]). \
agg([np.sum, np.mean, np.std, len,percentile(25),percentile(50),percentile(75)])
dfDepDelayTimeStats.reset_index(inplace=True)
dfDepDelayTimeStats.head()
# Out:
#   FlightDate Origin  DepDelay                                            \
#                           sum       mean        std  len  percentile_25
# 0 2008-01-01    ABE       472  78.666667  63.181221    6          34.00
# 1 2008-01-01    ABQ      1225  58.333333  52.977668   21          19.00
# 2 2008-01-01    ACT        26  26.000000        NaN    1          26.00
# 3 2008-01-01    ALB       781  55.785714  37.169422   14          29.25
# 4 2008-01-01    AMA        46  23.000000   4.242641    2          21.50
#
#
#    percentile_50  percentile_75
# 0           52.0         120.25
# 1           48.0          78.00
# 2           26.0          26.00
# 3           41.5          78.00
# 4           23.0          24.50
#
# [5 rows x 9 columns]

# %%
dfPlot = dfDepDelayTimeStats[dfDepDelayTimeStats['Origin']=='IAD']
print len(dfPlot)

figure(x_axis_type="datetime", tools="pan,wheel_zoom,box_zoom,reset,previewsave",background_fill="#FFFFFF")
sns.set_context("talk")
hold()

line(
    dfPlot['FlightDate'],                                       # x coordinates
    dfPlot['DepDelay']['percentile_25'],             # y coordinates
    color='#B9C7E7',                                         # set a color for the line
    legend='Departure-25%ile',                      # attach a legend label
    x_axis_type = "datetime",                           # NOTE: only needed on first
    line_width=2,
    tools="pan,wheel_zoom,box_zoom,reset,previewsave"   # NOTE: only needed on first
)

line(
    dfPlot['FlightDate'],                                       # x coordinates
    dfPlot['DepDelay']['percentile_50'],                                  # y coordinates
color='#4878CF',                                         # set a color for the line
        legend='Departure-Median',                                      # attach a legend label
    x_axis_type = "datetime",                           # NOTE: only needed on first
    line_width=4,
    tools="pan,wheel_zoom,box_zoom,reset,previewsave"   # NOTE: only needed on first
    
)

line(
    dfPlot['FlightDate'],                                       # x coordinates
    dfPlot['DepDelay']['mean'],                                  # y coordinates
color='#0033FF',                                         # set a color for the line
        legend='Departure-Mean',                                      # attach a legend label
    x_axis_type = "datetime",                           # NOTE: only needed on first,
    line_width=4,
    tools="pan,wheel_zoom,box_zoom,reset,previewsave"   # NOTE: only needed on first
)


line(
    dfPlot['FlightDate'],                                       # x coordinates
    dfPlot['DepDelay']['percentile_75'],                                  # y coordinates
color='#B9C7E7',                                         # set a color for the line
        legend='Departure-75%ile',                                      # attach a legend label
    x_axis_type = "datetime",                           # NOTE: only needed on first
    line_width=2,
    tools="pan,wheel_zoom,box_zoom,reset,previewsave"   # NOTE: only needed on first
)

curplot().title = "Departure Delay by Time" + " at " + dfPlot['Origin'].unique()[0] + " Airport"
grid().grid_line_alpha=0.3
grid().grid_line_color="black"

show()

dfPlot.reset_index('FlightDate',inplace=True)
s = dfPlot['DepDelay']['mean']
print s.describe()
sns.violinplot(s, inner="box", color="mediumseagreen",alpha=0.9)
# Out:
# 31
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>Bokeh Plot</title>
#         <script type="text/javascript">
# ...

# %%
# # dfPlot.reset_index('FlightDate',inplace=True)
# s1 = dfPlot['DepDelay']['mean']
# s2 = dfPlot['DepDelay']['std']/2+s1
# s3 = -dfPlot['DepDelay']['std']/2+s1
# # sns.color_palette("coolwarm", 3)
# # print s.describe()
# # sns.violinplot(s1, inner="box", color="pastel",alpha=0.9)
# ax = sns.tsplot(s1)
# ax = sns.tsplot(s2,color="#cccccc")
# ax = sns.tsplot(s3,color="#cccccc")
# sns.set_context("talk")
# # print s
# sns.axlabel("Day of Year", "Delay")
# ts = dfPlot['FlightDate']
# ts
# # [t for t in ts]
# ax.set_xticklabels([t for t in ts],rotation=45)

# %%
# ts = dfPlot['FlightDate']
# ts
# [t for t in ts]

# %%
# rng = pd.date_range('1/1/2011', periods=72, freq='H')
# ts = Series(np.random.randn(len(rng)), index=rng,name="data")
# # print ts[:5]
# # ts.name="date"
# sns.axes_style("white")
# sns.tsplot(ts)

# tf=pd.DataFrame(ts)
# tf.head()
# tf.reset_index(inplace=True)
# tf.dropna(inplace=True)
# tf.columns = ['date','data']
# tf.columns
# sns.tsplot(tf,time=tf['date'],condition=None)

# %%
dfPlot = dfArrDelayTimeStats[dfArrDelayTimeStats['Dest']=='AUS']
print len(dfPlot)
# Out:
# 31

# %%
dfPlot = dfArrDelayTimeStats[dfArrDelayTimeStats['Dest']=='AUS']
print len(dfPlot)
figure(x_axis_type="datetime", tools="pan,wheel_zoom,box_zoom,reset,previewsave")
hold()

line(
    dfPlot['FlightDate'],                                       # x coordinates
    dfPlot['ArrDelay']['percentile_25'],             # y coordinates
    color='#EADBD7',                                         # set a color for the line
    legend='Arrival Delay-25%ile',                      # attach a legend label
    x_axis_type = "datetime",                           # NOTE: only needed on first
    tools="pan,wheel_zoom,box_zoom,reset,previewsave"   # NOTE: only needed on first
)

line(
    dfPlot['FlightDate'],                                       # x coordinates
    dfPlot['ArrDelay']['percentile_50'],                                  # y coordinates
    color='#1F78B4',                                    # set a color for the line
    legend='Arrival Delay-Median',                                      # attach a legend label
    x_axis_type = "datetime",                           # NOTE: only needed on first
    tools="pan,wheel_zoom,box_zoom,reset,previewsave"   # NOTE: only needed on first
)

line(
    dfPlot['FlightDate'],                                       # x coordinates
    dfPlot['ArrDelay']['mean'],                                  # y coordinates
    color='#FB9A99',                                    # set a color for the line
    legend='Arrival Delay-Mean',                                      # attach a legend label
    x_axis_type = "datetime",                           # NOTE: only needed on first
    tools="pan,wheel_zoom,box_zoom,reset,previewsave"   # NOTE: only needed on first
)


line(
    dfPlot['FlightDate'],                                       # x coordinates
    dfPlot['ArrDelay']['percentile_75'],                                  # y coordinates
    color='#EADBD7',                                    # set a color for the line
    legend='Arrival Delay-75%ile',                                      # attach a legend label
    x_axis_type = "datetime",                           # NOTE: only needed on first
    tools="pan,wheel_zoom,box_zoom,reset,previewsave"   # NOTE: only needed on first
)


curplot().title = "Arrival Delay by Time" + " at " + dfPlot['Dest'].unique()[0] + " Airport"
grid().grid_line_alpha=0.3

show()
# Out:
# 31
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>Bokeh Plot</title>
#         <script type="text/javascript">
# ...

# %%
dfPlot.reset_index('FlightDate',inplace=True)
s = dfPlot['ArrDelay']['mean']
print s.describe()
sns.violinplot(s, inner="box", color="mediumseagreen",alpha=0.9)
# Out:
# count    31.000000
# mean     49.926137
# std      12.650087
# min      27.444444
# 25%      40.000000
# 50%      47.272727
# 75%      60.623798
# max      73.666667
# Name: mean, dtype: float64

# %%
dfMaster.columns
# Out:
# Index([u'Year', u'Month', u'DayofMonth', u'DayOfWeek', u'DepTime', u'CRSDepTime', u'ArrTime', u'CRSArrTime', u'UniqueCarrier', u'FlightNum', u'TailNum', u'ActualElapsedTime', u'CRSElapsedTime', u'AirTime', u'ArrDelay', u'DepDelay', u'Origin', u'Dest', u'Distance', u'TaxiIn', u'TaxiOut', u'Cancelled', u'CancellationCode', u'Diverted', u'CarrierDelay', u'WeatherDelay', u'NASDelay', u'SecurityDelay', u'LateAircraftDelay', u'Origin_airport', u'Origin_city', u'Origin_state', u'Origin_country', u'Origin_lat', u'Origin_long', u'Dest_airport', u'Dest_city', u'Dest_state', u'Dest_country', u'Dest_lat', u'Dest_long', u'Carrier_Description', u'FlightDate', u'Carrier_Description'], dtype='object')

# %%
dfDayOfWeekDepDelayStats = dfMaster[['DayOfWeek','DepDelay']][dfMaster['DepDelay'] > INPUT_DELAY].groupby([dfMaster['DayOfWeek']]).agg([np.mean])

del dfDayOfWeekDepDelayStats['DayOfWeek']
dfDayOfWeekDepDelayStats.reset_index(inplace=True)
dfDayOfWeekDepDelayStats.columns
# dfPlot = dfArrDelayTimeStats[dfArrDelayTimeStats['Dest']=='AUS']
# print len(dfPlot)

# 	1 (Monday) - 7 (Sunday)
# Out:
# MultiIndex(levels=[[u'DayOfWeek', u'DepDelay'], [u'mean', u'']],
#            labels=[[0, 1], [1, 0]])

# %%
dfDayOfWeekDepDelayStats['DepDelay']['mean']
# Out:
# 0    64.524306
# 1    62.319033
# 2    56.614520
# 3    61.205117
# 4    56.885302
# 5    58.421912
# 6    61.166764
# Name: mean, dtype: float64

# %%
labels = ['Mon', 'Tue', 'Wed', 'Thur','Fri','Sat','Sun']
plt.plot(dfDayOfWeekDepDelayStats['DayOfWeek'], dfDayOfWeekDepDelayStats['DepDelay']['mean'])
plt.xticks(dfDayOfWeekDepDelayStats['DayOfWeek'],labels, rotation=45)
# dfDayOfWeekDepDelayStats['DayOfWeek']
plt.ylabel="Average Delay in Minutes"
plt.xlabel="Day Of Week"
plt.show()

# %% [markdown]
# Day of Month vs Delays analysis

# %%
dfDayofMonthDepDelayStats = dfMaster[['DayofMonth','DepDelay']][dfMaster['DepDelay'] > 15].groupby([dfMaster['DayofMonth']]).agg([np.mean,len])

del dfDayofMonthDepDelayStats['DayofMonth']
dfDayofMonthDepDelayStats.reset_index(inplace=True)
dfDayofMonthDepDelayStats.columns

#   1 (Monday) - 7 (Sunday)
labels = xrange(1,31)
plt.plot(dfDayofMonthDepDelayStats['DayofMonth'], dfDayofMonthDepDelayStats['DepDelay']['mean'])
plt.xticks(dfDayofMonthDepDelayStats['DayofMonth'],labels, rotation=45)
# dfDayofMonthDepDelayStats['DayofMonth']
plt.ylabel="Average Delay in Minutes"
plt.xlabel="Day Of Week"
plt.show()
dfDayofMonthDepDelayStats

labels = xrange(1,31)
plt.plot(dfDayofMonthDepDelayStats['DayofMonth'], dfDayofMonthDepDelayStats['DepDelay']['len'])
plt.xticks(dfDayofMonthDepDelayStats['DayofMonth'],labels, rotation=45)
# dfDayofMonthDepDelayStats['DayofMonth']
plt.ylabel="Average Delay in Minutes"
plt.xlabel="Day Of Week"
plt.show()
dfDayofMonthDepDelayStats

dfDayofMonthDepArrStats = dfMaster[['DayofMonth','ArrDelay']][dfMaster['ArrDelay'] > 15].groupby([dfMaster['DayofMonth']]).agg([np.mean,len])

del dfDayofMonthDepArrStats['DayofMonth']
dfDayofMonthDepArrStats.reset_index(inplace=True)
dfDayofMonthDepArrStats.columns
# dfPlot = dfArrDelayTimeStats[dfArrDelayTimeStats['Dest']=='AUS']
# print len(dfPlot)

labels = xrange(1,31)
plt.plot(dfDayofMonthDepArrStats['DayofMonth'], dfDayofMonthDepArrStats['ArrDelay']['mean'])
plt.xticks(dfDayofMonthDepArrStats['DayofMonth'],labels, rotation=45)
# dfDayofMonthDepDelayStats['DayofMonth']
plt.ylabel="Average Delay in Minutes"
plt.xlabel="Day Of Week"
plt.show()
dfDayofMonthDepArrStats

labels = xrange(1,31)
plt.plot(dfDayofMonthDepArrStats['DayofMonth'], dfDayofMonthDepArrStats['ArrDelay']['len'])
plt.xticks(dfDayofMonthDepArrStats['DayofMonth'],labels, rotation=45)
# dfDayofMonthDepDelayStats['DayofMonth']
plt.ylabel="Average Delay in Minutes"
plt.xlabel="Day Of Week"
plt.show()
dfDayofMonthDepArrStats
# Out:
#     DayofMonth   ArrDelay
#                      mean   len
# 0            1  62.902176  5285
# 1            2  55.265609  6679
# 2            3  51.144390  5125
# 3            4  61.508060  3970
# 4            5  62.984361  4412
# 5            6  57.468991  4934
# 6            7  67.401851  3566
# 7            8  59.500842  3562
# 8            9  48.346083  2170
# 9           10  53.989177  3234
# 10          11  57.894632  2999
# 11          12  46.902818  1029
# 12          13  45.392311  2549
# 13          14  50.952250  2555
# 14          15  51.377103  2140
# 15          16  64.829979  1888
# 16          17  64.722999  5722
# 17          18  46.299891  4605
# 18          19  59.191892  2960
# 19          20  48.721466  2646
# 20          21  66.221941  5916
# 21          22  59.902958  5173
# 22          23  56.393001  3972
# 23          24  46.664574  3822
# 24          25  54.109922  4485
# 25          26  44.136477  2799
# 26          27  71.860126  5076
# ...

# %% [markdown]
# Busiest airport - Maps indicated by circle radius, busier the airport larger the circle

# %% [markdown]
# Busiest Route - Busier route is indicated by different color line.

# %%
d3 = pd.read_csv("C:\\Users\\Divyakumar\\Desktop\\Dec.csv",skiprows=0)
len(d3)
# Out:
# 544958

# %%
d3.columns
# Out:
# Index([u'index', u'Year', u'Month', u'DayOfWeek', u'DepTime', u'CRSDepTime', u'ArrTime', u'CRSArrTime', u'UniqueCarrier', u'FlightNum', u'TailNum', u'ActualElapsedTime', u'CRSElapsedTime', u'AirTime', u'ArrDelay', u'DepDelay', u'Origin', u'Dest', u'Distance', u'TaxiIn', u'TaxiOut', u'Cancelled', u'CancellationCode', u'Diverted', u'CarrierDelay', u'WeatherDelay', u'NASDelay', u'SecurityDelay', u'LateAircraftDelay'], dtype='object')

# %%
dfd3 = d3[['Dest','DepDelay']][d3['DepDelay'] > -100].groupby([d3['Dest']]).agg([np.mean,len])
len(dfd3)
dfd3.to_csv("C:\\Users\\Divyakumar\\Desktop\\dfd3.csv")

# del d3['DayofMonth']
# d3.reset_index(inplace=True)
# d3.columns

# #   1 (Monday) - 7 (Sunday)
# labels = xrange(1,31)
# plt.plot(d3['DayofMonth'], d3['DepDelay']['mean'])
# plt.xticks(d3['DayofMonth'],labels, rotation=45)
# # dfDayofMonthDepDelayStats['DayofMonth']
# plt.ylabel="Average Delay in Minutes"
# plt.xlabel="Day Of Week"
# plt.show()
# d3.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-173-eb4f3893b9ba> in <module>()
#       1 dfd3 = d3[['Dest','DepDelay']][d3['DepDelay'] > -100].groupby([d3['Dest']]).agg([np.mean,len])
#       2 len(dfd3)
# ----> 3 dfd3.sort([0][1])
#       4 dfd3.to_csv("C:\\Users\\Divyakumar\\Desktop\\dfd3.csv")
#       5
#
# IndexError: list index out of range

# %%
dfDayofMonthDepDelayStats = dfMaster[['DayofMonth','DepDelay']][dfMaster['DepDelay'] > 15].groupby([dfMaster['DayofMonth']]).agg([np.mean,len])

del dfDayofMonthDepDelayStats['DayofMonth']
dfDayofMonthDepDelayStats.reset_index(inplace=True)
dfDayofMonthDepDelayStats.columns

#   1 (Monday) - 7 (Sunday)
labels = xrange(1,31)
plt.plot(dfDayofMonthDepDelayStats['DayofMonth'], dfDayofMonthDepDelayStats['DepDelay']['mean'])
plt.xticks(dfDayofMonthDepDelayStats['DayofMonth'],labels, rotation=45)
# dfDayofMonthDepDelayStats['DayofMonth']
plt.ylabel="Average Delay in Minutes"
plt.xlabel="Day Of Week"
plt.show()
dfDayofMonthDepDelayStats

labels = xrange(1,31)
plt.plot(dfDayofMonthDepDelayStats['DayofMonth'], dfDayofMonthDepDelayStats['DepDelay']['len'])
plt.xticks(dfDayofMonthDepDelayStats['DayofMonth'],labels, rotation=45)
# dfDayofMonthDepDelayStats['DayofMonth']
plt.ylabel="Average Delay in Minutes"
plt.xlabel="Day Of Week"
plt.show()
dfDayofMonthDepDelayStats

dfDayofMonthDepArrStats = dfMaster[['DayofMonth','ArrDelay']][dfMaster['ArrDelay'] > 15].groupby([dfMaster['DayofMonth']]).agg([np.mean,len])

del dfDayofMonthDepArrStats['DayofMonth']
dfDayofMonthDepArrStats.reset_index(inplace=True)
dfDayofMonthDepArrStats.columns
# dfPlot = dfArrDelayTimeStats[dfArrDelayTimeStats['Dest']=='AUS']
# print len(dfPlot)

labels = xrange(1,31)
plt.plot(dfDayofMonthDepArrStats['DayofMonth'], dfDayofMonthDepArrStats['ArrDelay']['mean'])
plt.xticks(dfDayofMonthDepArrStats['DayofMonth'],labels, rotation=45)
# dfDayofMonthDepDelayStats['DayofMonth']
plt.ylabel="Average Delay in Minutes"
plt.xlabel="Day Of Week"
plt.show()
dfDayofMonthDepArrStats

labels = xrange(1,31)
plt.plot(dfDayofMonthDepArrStats['DayofMonth'], dfDayofMonthDepArrStats['ArrDelay']['len'])
plt.xticks(dfDayofMonthDepArrStats['DayofMonth'],labels, rotation=45)
# dfDayofMonthDepDelayStats['DayofMonth']
plt.ylabel="Average Delay in Minutes"
plt.xlabel="Day Of Week"
plt.show()
dfDayofMonthDepArrStats
